# %%
import os
import random
import string

def random_word(length):
    # Generates a random word of the given length
    letters = string.ascii_lowercase
    return ''.join(random.choice(letters) for i in range(length))

def rename_files_in_directory(directory, word_length=10):
    # Rename all files in the specified directory with a random word of the specified length
    for filename in os.listdir(directory):
        # Check if the current file is a file and not a directory
        if os.path.isfile(os.path.join(directory, filename)):
            # Generate a new file name with a random word
            new_filename = f"{random_word(word_length)}{os.path.splitext(filename)[1]}"
            # Define the full file paths
            old_file = os.path.join(directory, filename)
            new_file = os.path.join(directory, new_filename)
            # Rename the file
            os.rename(old_file, new_file)
            print(f"Renamed {filename} to {new_filename}")

# Path to the directory containing the images
image_directory = 'sanskrit_test_data/v_12'

# Call the function to rename the files in the directory
rename_files_in_directory(image_directory)
# Out:
# Renamed 014_06.jpg to xumjaqwynj.jpg
# Renamed 032_02.jpg to lfrvtrmuum.jpg
# Renamed 004_03.jpg to jpljgisziz.jpg
# Renamed 006_06.jpg to ptxajegyph.jpg
# Renamed 008_03.jpg to awwvfnsdlr.jpg
# Renamed 020_02.jpg to crzjjsaecl.jpg
# Renamed 016_03.jpg to csrovpakgo.jpg
# Renamed 043_02.jpg to htqpbhfdik.jpg
# Renamed 018_06.jpg to eujneplwpe.jpg
# Renamed 018_07.jpg to znzfqvwjjc.jpg
# Renamed 016_02.jpg to wvcoqyssms.jpg
# Renamed 020_03.jpg to jvosfvathn.jpg
# Renamed 001_26.jpg to psirywtnap.jpg
# Renamed 008_02.jpg to qaewhzkvsy.jpg
# Renamed 004_02.jpg to ukfknzzdnu.jpg
# Renamed 014_07.jpg to xguhriykic.jpg
# Renamed 014_05.jpg to zbqinzojvo.jpg
# Renamed 032_01.jpg to unlarfmuhm.jpg
# Renamed 006_05.jpg to wdtxaxfflp.jpg
# Renamed 001_18.jpg to hrqfghoars.jpg
# Renamed 001_24.jpg to zfnskqprgo.jpg
# Renamed 020_01.jpg to mcbinvbobm.jpg
# Renamed 011_09.jpg to gnqxndthgm.jpg
# Renamed 018_05.jpg to yabjygsfau.jpg
# Renamed 043_01.jpg to dhqvzfvnbo.jpg
# ...
